# %%
from google.cloud import bigquery

# %%
def read_from_bqtable(bq_query):
    client = bigquery.Client.from_service_account_json('../Sales-Data-Cleanup/bigquery_credentials/credentials.json')
    bq_data = client.query(bq_query).to_dataframe()
    return bq_data

table_id = 'iprocure-edw.iprocure_edw.products_cleaned'
query = f"""
        SELECT *
        FROM {table_id}
        """

bq_df = read_from_bqtable(query)

bq_df.to_csv('product_details.csv', index = False)

display(bq_df.head())
# Out:
#    product_id  user_group_id_super_owner product_category sub_category
# 0      297644                         18    MULTIVITAMINS         None  \
# 1      297650                         18    MULTIVITAMINS         None
# 2      297337                         18    MULTIVITAMINS         None
# 3      297639                         18    MULTIVITAMINS         None
# 4      297287                         18    MULTIVITAMINS         None
#
#                       product_name product_type product_code distributor_code
# 0                   Multidex 100ml                      None             None  \
# 1      vitamin B Complex Injection                      None             None
# 2  Vitamin-B Complex (Medidlex)Inj                      None             None
# 3                  Nutrivita 100ml                      None             None
# 4          Multivitamin Zain 100ml                      None             None
#
#   product_units product_unitCost  ... barcode_type product_family_id
# ...

# %%
import pandas as pd

df = pd.read_csv('ipos_products.csv')
df.head()
# Out:
# /tmp/ipykernel_7277/1366723730.py:3: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('ipos_products.csv')
#    product_id  user_group_id_super_owner product_category sub_category
# 0      297644                         18    MULTIVITAMINS          NaN  \
# 1      297650                         18    MULTIVITAMINS          NaN
# 2      297337                         18    MULTIVITAMINS          NaN
# 3      297639                         18    MULTIVITAMINS          NaN
# 4      297287                         18    MULTIVITAMINS          NaN
#
#                       product_name product_type product_code distributor_code
# 0                   Multidex 100ml          NaN          NaN              NaN  \
# 1      vitamin B Complex Injection          NaN          NaN              NaN
# 2  Vitamin-B Complex (Medidlex)Inj          NaN          NaN              NaN
# ...
