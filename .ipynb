# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings(action='ignore')

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('clean_prod_datasets/new_cleaned_products.csv')
df = df.reset_index()
df.head()
# Out:
#    index  product_id  user_group_id_super_owner product_category sub_category
# 0      0      297644                         18    MULTIVITAMINS          NaN  \
# 1      1      297650                         18    MULTIVITAMINS          NaN
# 2      2      297337                         18    MULTIVITAMINS          NaN
# 3      3      297639                         18    MULTIVITAMINS          NaN
# 4      4      297287                         18    MULTIVITAMINS          NaN
#
#                       product_name product_type product_code distributor_code
# 0                   multidex 100ml          NaN          NaN              NaN  \
# 1      vitamin b complex injection          NaN          NaN              NaN
# 2  vitamin-b complex (medidlex)inj          NaN          NaN              NaN
# 3                  nutrivita 100ml          NaN          NaN              NaN
# 4          multivitamin zain 100ml          NaN          NaN              NaN
#
#   product_units  product_unitCost product_manufacturer product_distributor
# 0           NaN               0.0                  NaN                 NaN  \
# 1           NaN               0.0                  NaN                 NaN
# 2           NaN               0.0                  NaN                 NaN
# 3           NaN               0.0                  NaN                 NaN
# 4           NaN               0.0                  NaN                 NaN
#
#    create_date  update_date  vat  product_weight  carton_size
# 0   1636533977   1636535177  NaN             0.0            1  \
# 1   1636533977   1636535177  NaN             0.0            1
# 2   1636533971   1636535171  NaN             0.0            1
# 3   1636533977   1636535177  NaN             0.0            1
# 4   1636533971   1636535171  NaN             0.0            1
#
#    product_listStatus  active_status  distributor_type  bundle_type
# 0                   0              4                 1            1  \
# 1                   0              4                 1            1
# 2                   0              4                 1            1
# 3                   0              4                 1            1
# 4                   0              4                 1            1
#
#    barcode_type  product_family_id  cold_chain product_industry
# 0             0                  0           0      Agriculture  \
# 1             0                  0           0      Agriculture
# 2             0                  0           0      Agriculture
# 3             0                  0           0      Agriculture
# 4             0                  0           0      Agriculture
#
#    product_industry_id                                datastream_metadata
# 0                  156  {'uuid': 'f60a3b4c-8682-488b-a8c9-e62f10011110...  \
# 1                  156  {'uuid': 'f60a3b4c-8682-488b-a8c9-e62f10100100...
# 2                  156  {'uuid': '81bd8b78-11b7-4543-a1e4-ca7001101011...
# 3                  156  {'uuid': 'f60a3b4c-8682-488b-a8c9-e62f10011001...
# 4                  156  {'uuid': '81bd8b78-11b7-4543-a1e4-ca7000111001...
#
#       best_product_match best_manufacturer_match  product_match_score
# 0           albendex 100                     NaN                 0.62  \
# 1      vitamet injection                     NaN                 0.73
# 2  vita-vit complex plus                     NaN                 0.58
# 3               nutrivit                     NaN                 0.70
# 4           multivitamin                     NaN                 0.69
#
#    manufacturer_match_score        correct_product_match
# 0                       1.0               multidex 100ml  \
# 1                       1.0  vitamin b complex injection
# 2                       1.0  vitamin b complex injection
# 3                       1.0              nutrivita 100ml
# 4                       1.0      multivitamin zain 100ml
#
#   correct_manufacturer_match correct_category_name correct_sub_category
# 0                        NaN               hygiene                  NaN  \
# 1                        NaN          anaesthetics                  NaN
# 2                        NaN          anaesthetics                  NaN
# 3                        NaN         multivitamins                  NaN
# 4                        NaN        immunologicals                  NaN
#
#   correct_product_type
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %%
# df = df[['index', 'product_id', 'product_name', 'product_manufacturer', 'product_type', 'correct_product_match', 'correct_manufacturer_match', 'correct_product_type']]
# df = df.sort_values(by='correct_product_match').reset_index(drop=True)
# # df.to_csv('ipos_list_of_product.csv', index=False)
# df.head()

# %%
df = df[['product_name', 'correct_product_match', 
         'product_manufacturer', 'correct_manufacturer_match', 
         'product_category', 'correct_category_name', 
         'sub_category', 'correct_sub_category', 
         'product_type', 'correct_product_type']]
df.tail()
# Out:
#               product_name correct_product_match
# 959596    vapcomore 20% sp             vapcomore  \
# 959597  premierlick maziwa        prolick maziwa
# 959598               phone      q-508 copy phone
# 959599          cold start        cold cup 100ml
# 959600              silcon          silcon 300ml
#
#                                      product_manufacturer
# 959596  vapco (veterinary and agricultural products ma...  \
# 959597                                                380
# 959598                                               3500
# 959599                                                  #
# 959600                                                999
#
#                                correct_manufacturer_match
# 959596   vapco(veterinary and agriculture products man...  \
# 959597                                                380
# 959598                                             500 ml
# 959599                                                  #
# 959600                                                999
#
#                 product_category correct_category_name sub_category
# 959596             Agrochemicals         agrochemicals          NaN  \
# 959597  Minerals and Supplements   veterinary products          NaN
# 959598               electronics           accessories          NaN
# 959599               Accessories                engine          NaN
# 959600                      Body   tools and equipment          NaN
#
#        correct_sub_category      product_type correct_product_type
# 959596                  NaN   insectcide 100g    insecticide 100ml
# 959597                  NaN               2kg                  2kg
# 959598                  NaN       restoration          restoration
# 959599                  NaN  holts cold start     holts cold start
# 959600                  NaN          grey 85g             reno 85g
